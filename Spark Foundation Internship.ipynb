# %% [markdown]
# # **The Sparks Foundation Internship - Data Science & Business Analytics**

# %% [markdown]
# ## Exploratory Data Analysis on **SUPERSTORE DATA**

# %% [markdown]
# ## Objectives:-
# ### *1) To perform exploratory Data Analysis*
# ### *2) As a business manager, find out business problems*
# ### *3) Identify key areas for improving profits*

# %% [markdown]
# ## Importing required libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\\Users\\ajayg\\Downloads\\SampleSuperstore.csv', encoding = 'unicode_escape') 
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# 1        False         False  False     False     False   False
# 2        False         False  False     False     False   False
# 3        False         False  False     False     False   False
# 4        False         False  False     False     False   False
# ...        ...           ...    ...       ...       ...     ...
# 9989     False         False  False     False     False   False
# 9990     False         False  False     False     False   False
# 9991     False         False  False     False     False   False
# 9992     False         False  False     False     False   False
# 9993     False         False  False     False     False   False
#
# [9994 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
df.shape
# Out:
# (9977, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis & Data Visualization

# %% [markdown]
# ### *What are total Sales and Profits of the company by segment?*

# %%
Sales_and_Profits = df.groupby("Segment").sum().iloc[:,[8,-1]].sum()
round(Sales_and_Profits,2) # Rounding Numericala entries to 2 decimal places
# Out:
# Sales     2296195.59
# Profit     286241.42
# dtype: float64

# %% [markdown]
# ### Total Sales = 22,96,195.56
# ### Total Profits = 2,86,241.42

# %% [markdown]
# ### *Top 10 States by Sales and Profits*

# %%
Top_10_Sales = df.groupby("State").Sales.sum().nlargest(n =10)
Top_10_Profits = df.groupby("State").Profit.sum().nlargest(n =10)

# %%
Top_10_Sales
# Out:
# State
# California      457576.2715
# New York        310827.1510
# Texas           170124.5418
# Washington      138560.8100
# Pennsylvania    116496.3620
# Florida          89473.7080
# Illinois         80162.5370
# Ohio             77976.7640
# Michigan         75879.6440
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
Top_10_Sales.index
# Out:
# Index(['California', 'New York', 'Texas', 'Washington', 'Pennsylvania',
#        'Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia'],
#       dtype='object', name='State')

# %%
Top_10_Profits.index
# Out:
# Index(['California', 'New York', 'Washington', 'Michigan', 'Virginia',
#        'Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware'],
#       dtype='object', name='State')

# %% [markdown]
# ### Top 10 States by Sales:
# 'California', 'New York', 'Texas', 'Washington', 'Pennsylvania','Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia'
#
# ### Top 10 States by Profit:
# 'California', 'New York', 'Washington', 'Michigan', 'Virginia','Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware'

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn')
ax = Top_10_Sales.plot(kind ='bar', figsize =(14,8), fontsize =14)
ax.set_xlabel("States", fontsize =13)
ax.set_ylabel("Total Sales",fontsize =13)
ax.set_title("Top 10 States by Sales",fontsize =16)
plt.show()

# %%
plt.style.use('seaborn')
ax = Top_10_Profits.plot(kind ='bar', figsize =(14,8), fontsize =14)
ax.set_xlabel("States", fontsize =13)
ax.set_ylabel("Total Profits",fontsize =13)
ax.set_title("Top 10 States by Profits",fontsize =16)
plt.show()

# %% [markdown]
# #### California and New York are far ahead of their competitor states.

# %%
# Pair_plot
financial = df.loc[:,['Sales','Quantity','Discount','Profit']]
sns.pairplot(financial)

# %% [markdown]
# #### In above we see that there is some relation between sales and profit and also there is some relation between Discount and Profit. Now To see what exact relation between those entities we plot the heat_map. so we get more clearity

# %%
correlation=financial.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### From Above map we infer that,
# #### 1) Sales and Profits are positively correlated
# #### 2) Discount and Profits are Negatively correlated
#
# ##### Hence we consider these cases and proceed further

# %% [markdown]
# ## Case-1 When Discount is 0

# %%
data=df[df['Discount']==0]
sns.relplot(x='Sales',y='Profit',data=data)

# %% [markdown]
# #### Hence we can say that there is positive relation between Profit and sales when Discount is 0 so Now we will plot heat_map to get correlaton.

# %%
numerical_features = data.select_dtypes(include='number') 
correlation = numerical_features.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Hence, we see that There is strong correlation between sales and Profit i.e 0.92

# %%
#Rel_plot with respect category
sns.relplot(x='Sales',y='Profit',hue='Category',data=data)

# %% [markdown]
# #### Furniture category is not making profits whereas Technology category is making huge profit and sales at the same time when discount = 0

# %% [markdown]
# ## Case-2 When Discount is Not 0

# %%
data1=df[df['Discount']!=0]
sns.relplot(x='Sales',y='Profit',hue='Discount',data=data1)

# %% [markdown]
# #### In above graph we can see that as percentage of Discount increases the sales also increses but profit decreases
# #### Now let's check how it can effect on different sectors of business

# %%
sns.relplot(x='Sales',y='Profit',hue='Category',data=data1)

# %%
numerical_features = data1.select_dtypes(include='number') 
correlation=numerical_features.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Here, we can se that there is a negative correlation between sales and profit when discount!=0 unlike when discount is 0

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.barplot(x = 'Sub-Category' , y = 'Profit' , data = data1)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Profit'>

# %% [markdown]
# #### Here we see that copiers has highest Profit and Machines has highest loss

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.barplot(x = 'Sub-Category' , y = 'Sales' , data = data1)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Sales'>

# %% [markdown]
# ##### Here we see that copiers has highest sale and Machines has second highest sales
#
# ##### In above two graph we can see that 'Machines' has second highest sale but due to large discount, it is in loss and in second graph we can see that sales in 'Fasteners','labels'and 'Art' category are so weak, so we have to concentrate on these sub-category businesses
#
# #### Discounts are triggering losses

# %% [markdown]
# ## Distrubution of Profits across diffrent regions by Segments

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = df , x = "Region",y = "Profit" ,hue = "Segment")
plt.show()

# %% [markdown]
# #### Overall each Segment is profitable.

# %% [markdown]
# ## Profit distribution across Region by category

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = df , x = "Region",y = "Profit" ,hue = "Category")
plt.show()

# %% [markdown]
# #### "Furniture" Category is the only loss making sector and that to only in Central Region

# %% [markdown]
# ##  Investigating losses in Furniture category in the Central region

# %%
# Grouping Data by Region and only slicing Data for Central Region from whole Data Set
gb_Central = df[df['Region'] == 'Central']
gb_Central
# Out:
#            Ship Mode      Segment        Country          City      State  \
# 14    Standard Class  Home Office  United States    Fort Worth      Texas
# 15    Standard Class  Home Office  United States    Fort Worth      Texas
# 16    Standard Class     Consumer  United States       Madison  Wisconsin
# 21    Standard Class    Corporate  United States       Fremont   Nebraska
# 22    Standard Class    Corporate  United States       Fremont   Nebraska
# ...              ...          ...            ...           ...        ...
# 9961     First Class  Home Office  United States       Houston      Texas
# 9962     First Class  Home Office  United States       Houston      Texas
# 9972  Standard Class     Consumer  United States       Houston      Texas
# 9982  Standard Class     Consumer  United States  Grand Rapids   Michigan
# 9983  Standard Class     Consumer  United States  Grand Rapids   Michigan
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 14          76106  Central  Office Supplies   Appliances   68.8100         5
# 15          76106  Central  Office Supplies      Binders    2.5440         3
# 16          53711  Central  Office Supplies      Storage  665.8800         6
# 21          68025  Central  Office Supplies          Art   19.4600         7
# 22          68025  Central  Office Supplies   Appliances   60.3400         7
# ...           ...      ...              ...          ...       ...       ...
# 9961        77041  Central  Office Supplies        Paper   65.5840         2
# 9962        77041  Central        Furniture    Bookcases  383.4656         4
# 9972        77041  Central  Office Supplies    Envelopes   99.5680         2
# 9982        49505  Central  Office Supplies        Paper   35.5600         7
# 9983        49505  Central       Technology       Phones   97.9800         2
#
#       Discount    Profit
# 14        0.80 -123.8580
# 15        0.80   -3.8160
# 16        0.00   13.3176
# 21        0.00    5.0596
# 22        0.00   15.6884
# ...        ...       ...
# 9961      0.20   23.7742
# 9962      0.32  -67.6704
# 9972      0.20   33.6042
# 9982      0.00   16.7132
# 9983      0.00   27.4344
#
# [2319 rows x 13 columns]

# %%
# Investing Further in cenral Region 
plt.figure(figsize = (12,4))
sns.set(font_scale=1.5, palette= "viridis")
sns.barplot(data = gb_Central, x = "Category",y = "Profit" ,hue = "Ship Mode")
plt.title("Investigation of central region: Profit making(by Ship Mode)")
plt.show()

# %% [markdown]
# #### Losses are inccured in Furniture Cateory irrespective to ship mode in Central Region

# %% [markdown]
# ## Investigating individual performance by states in the central region

# %%
gb_Category_Furniture = df[(df['Region'] == 'Central') & (df['Category'] == 'Furniture')]            
gb_Category_Furniture
# Out:
#            Ship Mode      Segment        Country          City    State  \
# 36       First Class    Corporate  United States    Richardson    Texas
# 38    Standard Class  Home Office  United States       Houston    Texas
# 39    Standard Class  Home Office  United States       Houston    Texas
# 51    Standard Class     Consumer  United States    New Albany  Indiana
# 52    Standard Class     Consumer  United States    New Albany  Indiana
# ...              ...          ...            ...           ...      ...
# 9903  Standard Class     Consumer  United States    Carrollton    Texas
# 9917    Second Class     Consumer  United States        Marion     Iowa
# 9919  Standard Class    Corporate  United States         Bryan    Texas
# 9947    Second Class    Corporate  United States  Indianapolis  Indiana
# 9962     First Class  Home Office  United States       Houston    Texas
#
#       Postal Code   Region   Category Sub-Category      Sales  Quantity  \
# 36          75080  Central  Furniture  Furnishings   190.9200         5
# 38          77041  Central  Furniture    Bookcases   532.3992         3
# 39          77041  Central  Furniture       Chairs   212.0580         3
# 51          47150  Central  Furniture  Furnishings     6.1600         2
# 52          47150  Central  Furniture       Chairs    89.9900         1
# ...           ...      ...        ...          ...        ...       ...
# 9903        75007  Central  Furniture  Furnishings    25.1280         3
# 9917        52302  Central  Furniture  Furnishings    14.9100         3
# 9919        77803  Central  Furniture       Chairs   528.4300         5
# 9947        46203  Central  Furniture       Chairs  1925.8800         6
# 9962        77041  Central  Furniture    Bookcases   383.4656         4
#
#       Discount    Profit
# 36        0.60 -147.9630
# 38        0.32  -46.9764
# 39        0.30  -15.1470
# 51        0.00    2.9568
# 52        0.00   17.0981
# ...        ...       ...
# 9903      0.60   -6.9102
# 9917      0.00    4.6221
# 9919      0.30 -143.4310
# 9947      0.00  539.2464
# 9962      0.32  -67.6704
#
# [480 rows x 13 columns]

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Sub-Category")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Sub Category)", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Segment")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Segment)", fontsize = 20)
plt.show()

# %% [markdown]
# ### Texas and Illiois are only two states contributing to all the losses in Furniture category in the Central Region
# ### Losses in Tables Sub Category is significanlty high.

# %% [markdown]
# ## *So, what is it they are doing diffrently?*

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Discount" ,hue = "Sub-Category")
plt.title("Discounts provided by each state", fontsize = 20)
plt.show()

# %% [markdown]
# ## Texas and Illinois are only states providing discounts in the whole central region this justifies high positive correlation between postal codes and discounts.
# ## Also, these discounts are very high!
# ## *1. 60% on Furnishings*
# ## *2. 30% on Bookcases and Chairs*
# ## *3. 50% disount on Tables in Illinois and 30% in Texas*
# ## Are these discounts driving sales up?.... NO!

# %%
plt.figure(figsize = (10,10))
sns.set(font_scale=1.5)
sns.lmplot(data = gb_Category_Furniture , x = "Discount", y ="Sales", aspect = 1, height = 8, col ="Sub-Category", col_wrap= 2)
plt.show()

# %% [markdown]
# #### Sales tend to do down when discounts go up in 3 out of 4 "Subcategories" and also in overall Furniture Category Sales in the Central Region.

# %% [markdown]
# ### Some more insights regarding Distribution of data

# %%
sns.boxplot(x='Category',y='Profit',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Profit'>

# %% [markdown]
# #### We can see that variation in Technology sector is more as compared to the other two sector

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = 'Category' , y = 'Discount' , data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Discount'>

# %% [markdown]
# ### Here, we can see that more discount is provided in the category of furniture leading to huge losses so this is weak spot where business should work on

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = 'Category' , y = 'Sales' , data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = 'Category' , y = 'Profit' , data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Profit'>

# %% [markdown]
# ## From the three plots plotted above, we can say that :-
# #### *1) More Discount is given in Furniture category and less Discount is given in Technology category businesses*
# #### *2) Sales of Technology category businesses are more as compared to Furniture category*
# #### *3) Profit of Technology category businesses are more as compared to Furniture category*

# %% [markdown]
# # Insights from Exploratory Data Analysis (Summary)
#
# ## Q. What are total Sales and Profits of the company?
# ### 1) Total Sales = 22,96,195.56
# ### 2) Total Profits = 2,86,241.42
#
#
# ## Q. Top 10 States by Sales and Profits
# ### -Top 10 States by Sales: 'California', 'New York', 'Texas', 'Washington', 'Pennsylvania','Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia'
# ### -Top 10 States by Profit: 'California', 'New York', 'Washington', 'Michigan', 'Virginia','Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware'
# ### -Californi and New York are far ahead of their competitor states in terms of Profits.
# ### -Discounts are triggering losses.
#
#
# ## Q. Distrubution of Profits across diffrent regions
# ### -Overall each Segment is profitable.
#
#
# ## Q. Profit distribution by Region
# ### -"Furniture" Category is the only loss making sector that to only in Central Region
#
#
# ## Q. Investigating losses in Furniture category in the Central region
# ### -Losses are inccured in Furniture Cateory irrespective to ship mode.
#
#
# ## Q. Investigating individual performance by states in the central region
# ### -Texas and Illiois are only two states contributing to all the losses in Furniture category in the Central Region
# ### -Losses in Tables Sub Category is significanlty high.
#
#
# ## Q. So, what is it they are doing diffrently?
# ### -Texas and Illinois are only states providing discounts in the whole central region this justifies high positive correlation between postal codes and discounts.
# ### -Also, these discounts are crazy high!
# #### 1)60% on Furnishings
# #### 2)30% on Bookcases and Chairs
# #### 3)50% disount on Tables in Illinois and 30% in Texas
#
#
# ## Q. Are these discounts driving sales up?.... NO!
# ### -Actually Sales tend to do down when discounts go up in 3 out of 4 "Subcategories" and also in overall Furniture Category Sales in the Central Region.

# %% [markdown]
# ## Conclusion
# #### From All these analysis we finally conclude that,
# 1) If we give more Discount on products our sales goes increses but Profit get down.
# 2) In Technology category business we get more Profit as compared to other two business.These is because of we given less Discount.
# 3) Here we also focus on our Office Supplies category business because sales of these category is less as compared to other two.
# 4) Also Sales in 'Fasteners','labels'and 'Art' category are so weak.so we have to concentrate on these sub-category businesses.
# 5) We have to concentrate on the Sales of 'West Virginia' State and 'San Luis Obispo' and 'Woodland' City.
# 6) To rise the profits , we first need to sell consumer segment products more .
# 7) For enhancing the profits , we need to sell more to the states which are liking our products¶ like NEWYORK and CALIFORNIA .
#
# #### Hence To get good profit in any business one should focus on increasing sales and not ignoring the discount factor as it plays an important role
